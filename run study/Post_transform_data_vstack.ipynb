# %%
# %pylab inline
from scipy.io import loadmat
import seaborn as sns
import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = []#load in all the subjects data
lst = ["s1","s2","s3","s5","s6","s7","s8","s10"]
for i in lst:
    a=np.load('runs_study_occipital_%s.npy'% i)
    data.append(a)

# %%
x = np.load('runs_study_occipital_s1.npy')
x.shape
# Out:
# (512, 5, 28)

# %%
data2 = []#load in all the subjects data
lst=["s1","s2","s3","s5","s6","s7","s8","s10"]
for i in lst:
    a = np.load('runs_study_vt_%s.npy'% i)
    data2.append(a)

# %%
data_all = numpy.stack(data,axis=3)#turn list of arrays into array

# %%
data_all2 = numpy.stack(data2,axis=3)#turn list into array

# %%
data_all.shape #5 levels, 28 orientations, 8 subjects;
#np.save("allsubjs_vstacked_readyfor_classification_occipital",data_all)
# Out:
# (512, 5, 28, 8)

# %%
data_all2.shape
# Out:
# (512, 5, 28, 8)

# %%
data_all2.shape #1230 TR, 5 levels, 28 orientations, 18 subjects;
#np.save("allsubjs_vstacked_readyfor_classification_vt",data_all2)
# Out:
# (512, 5, 28, 8)
